# %% [markdown]
# <a href="https://colab.research.google.com/github/Beatrice-fabien/TD/blob/main/Beatrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS PyMultiDictionary ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# ...

# %%
from PyMultiDictionary import MultiDictionary
from gtts import gTTS
from IPython.display import Audio, display, clear_output
import ipywidgets as widgets

# === Fonction pour faire parler avec gTTS ===
def parler(texte):
    print("🗣️ Assistant:", texte)
    tts = gTTS(texte, lang='fr')
    tts.save("reponse.mp3")
    display(Audio("reponse.mp3", autoplay=True))

# === Dictionnaire français ===
dico = MultiDictionary()

def trouver_synonymes_fr(mot):
    try:
        synonymes = dico.synonym('fr', mot)
        return synonymes if synonymes else []
    except:
        return []

def trouver_contraires_fr(mot):
    try:
        contraires = dico.antonym('fr', mot)
        return contraires if contraires else []
    except:
        return []

# === Widgets (interface) ===
entree_mot = widgets.Text(
    value='',
    placeholder='Entre un mot en français (ex: heureux, rapide, gentil)',
    description='Mot:',
    disabled=False,
    layout=widgets.Layout(width='60%')
)

bouton_syno = widgets.Button(description="🔁 Synonymes", button_style='success')
bouton_contraire = widgets.Button(description="↔️ Contraires", button_style='info')
bouton_stop = widgets.Button(description="❌ Quitter", button_style='danger')

sortie = widgets.Output()

# === Fonctions des boutons ===
def afficher_synonymes(b):
    with sortie:
        clear_output()
        mot = entree_mot.value.strip().lower()
        if not mot:
            parler("Merci d’entrer un mot.")
            return
        synonymes = trouver_synonymes_fr(mot)
        if synonymes:
            resultat = ", ".join(synonymes[:5])
            parler(f"Les synonymes de {mot} sont : {resultat}.")
        else:
            parler(f"Je n’ai trouvé aucun synonyme pour {mot}.")

def afficher_contraires(b):
    with sortie:
        clear_output()
        mot = entree_mot.value.strip().lower()
        if not mot:
            parler("Merci d’entrer un mot.")
            return
        contraires = trouver_contraires_fr(mot)
        if contraires:
            resultat = ", ".join(contraires[:5])
            parler(f"Les contraires de {mot} sont : {resultat}.")
        else:
            parler(f"Je n’ai trouvé aucun contraire pour {mot}.")

def quitter(b):
    with sortie:
        clear_output()
        parler("Au revoir et à bientôt !")
        print("👋 Fin du programme.")

# === Liaison des boutons à leurs fonctions ===
bouton_syno.on_click(afficher_synonymes)
bouton_contraire.on_click(afficher_contraires)
bouton_stop.on_click(quitter)

# === Affichage de l’interface ===
parler("Bonjour ! Je suis ton assistant de synonymes et contraires en français.")
display(entree_mot, widgets.HBox([bouton_syno, bouton_contraire, bouton_stop]), sortie)
# Out:
# 🗣️ Assistant: Bonjour ! Je suis ton assistant de synonymes et contraires en français.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Text(value='', description='Mot:', layout=Layout(width='60%'), placeholder='Entre un mot en français (ex: heur…
# ...
# Output()
